# %% [markdown]
# # Problem 1:

# %%
import numpy as np,pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df1=pd.read_excel('data1.xlsx')
# Out:
#     Unnamed: 0                                 Unnamed: 1      Unnamed: 2  \
# 0     Car_Name                                       Year   Selling_Price
# 1         ritz                                       2014            3.35
# 2          sx4                                       2013            4.75
# 3         ciaz                                       2017            7.25
# 4      wagon r                                       2011            2.85
# ..         ...                                        ...             ...
# 411        NaN                                        NaN             NaN
# 412        NaN                                        NaN             NaN
# 413        NaN         metrics.mean_absolute_error(y_test   predictions))
# 414        NaN          metrics.mean_squared_error(y_test   predictions))
# 415        NaN  np.sqrt(metrics.mean_squared_error(y_test  predictions)))
#
#         Unnamed: 3  Unnamed: 4 Unnamed: 5   Unnamed: 6    Unnamed: 7  \
# 0    Present_Price  Kms_Driven  Fuel_Type  Seller_Type  Transmission
# 1             5.59       27000     Petrol       Dealer        Manual
# 2             9.54       43000     Diesel       Dealer        Manual
# 3             9.85        6900     Petrol       Dealer        Manual
# 4             4.15        5200     Petrol       Dealer        Manual
# ..             ...         ...        ...          ...           ...
# 411            NaN         NaN        NaN          NaN           NaN
# 412            NaN         NaN        NaN          NaN           NaN
# 413            NaN         NaN        NaN          NaN           NaN
# 414            NaN         NaN        NaN          NaN           NaN
# 415            NaN         NaN        NaN          NaN           NaN
#
#     Unnamed: 8
# 0        Owner
# 1            0
# 2            0
# 3            0
# 4            0
# ..         ...
# 411        NaN
# 412        NaN
# 413        NaN
# 414        NaN
# 415        NaN
#
# [416 rows x 9 columns]

# %%
df1.head()
# Out:
#   Unnamed: 0 Unnamed: 1     Unnamed: 2     Unnamed: 3  Unnamed: 4 Unnamed: 5  \
# 0   Car_Name       Year  Selling_Price  Present_Price  Kms_Driven  Fuel_Type
# 1       ritz       2014           3.35           5.59       27000     Petrol
# 2        sx4       2013           4.75           9.54       43000     Diesel
# 3       ciaz       2017           7.25           9.85        6900     Petrol
# 4    wagon r       2011           2.85           4.15        5200     Petrol
#
#     Unnamed: 6    Unnamed: 7 Unnamed: 8
# 0  Seller_Type  Transmission      Owner
# 1       Dealer        Manual          0
# 2       Dealer        Manual          0
# 3       Dealer        Manual          0
# 4       Dealer        Manual          0

# %%
df1.describe()
# Out:
#        Unnamed: 0  Unnamed: 1  Unnamed: 2  Unnamed: 3  Unnamed: 4 Unnamed: 5  \
# count         301         308      305.00       302.0         302        302
# unique         98          24      160.00       148.0         207          5
# top          city        2015        0.45         9.4       45000     Petrol
# freq           26          60        8.00        15.0           9        239
#
#        Unnamed: 6 Unnamed: 7  Unnamed: 8
# count         302        301         301
# unique          4          3           4
# top        Dealer     Manual           0
# freq          194        260         289

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 416 entries, 0 to 415
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  301 non-null    object
#  1   Unnamed: 1  308 non-null    object
#  2   Unnamed: 2  305 non-null    object
#  3   Unnamed: 3  302 non-null    object
#  4   Unnamed: 4  302 non-null    object
#  5   Unnamed: 5  302 non-null    object
#  6   Unnamed: 6  302 non-null    object
#  7   Unnamed: 7  301 non-null    object
#  8   Unnamed: 8  301 non-null    object
# dtypes: object(9)
# memory usage: 29.4+ KB

# %%
df1.duplicated().sum()
# Out:
# 109

# %%
df1.isnull().sum()
# Out:
# Unnamed: 0    115
# Unnamed: 1    108
# Unnamed: 2    111
# Unnamed: 3    114
# Unnamed: 4    114
# Unnamed: 5    114
# Unnamed: 6    114
# Unnamed: 7    115
# Unnamed: 8    115
# dtype: int64

# %%
df1['unnamed: 0']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\Anaconda\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3628             try:
# -> 3629                 return self._engine.get_loc(casted_key)
#    3630             except KeyError as err:
#
# C:\Anaconda\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# C:\Anaconda\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'unnamed: 0'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_19800\4189380058.py in <module>
# ----> 1 df1['unnamed: 0']
#
# C:\Anaconda\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3503             if self.columns.nlevels > 1:
#    3504                 return self._getitem_multilevel(key)
# -> 3505             indexer = self.columns.get_loc(key)
#    3506             if is_integer(indexer):
#    3507                 indexer = [indexer]
#
# C:\Anaconda\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3629                 return self._engine.get_loc(casted_key)
#    3630             except KeyError as err:
# -> 3631                 raise KeyError(key) from err
#    3632             except TypeError:
#    3633                 # If we have a listlike key, _check_indexing_error will raise
#
# KeyError: 'unnamed: 0'
